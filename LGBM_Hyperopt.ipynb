# %% [markdown]
# This notebook is downloaded from: https://www.kaggle.com/tommy1028/lightgbm-starter-with-feature-engineering-idea

# %% [markdown]
# # LightGBM starter with feature engineering idea
# ***I am creating this note mostly for myself to re-organize my ideas. Please leave your comments and/or advice if you find the room I can improve my coding/model builing to go further.***
#
#
# We will predict **the realized volatility of the next ten-minutes time window** with two data sets of the last ten minutes (600 seconds).One dataset contains ask and bid prices of almost each second, which allows us to calculate the realized volatility of the last ten minutes.The other dataset contains the actual record of stock trading, which is more sparse.
#
# Please look at this notebook for the detailed explanation: https://www.kaggle.com/jiashenliu/introduction-to-financial-concepts-and-data
#
# As for EDA, you may find this notebook useful: https://www.kaggle.com/chumajin/optiver-realized-eda-for-starter-english-version
#
# Thank you!

# %% [markdown]
# ### Contribution from the commmunity
# **The codes for showing Feature Importance is kindly prepared by this expert: https://www.kaggle.com/something4kag
# and extracted by this notebook: https://www.kaggle.com/something4kag/lightgbm-starter-with-fe-and-importance**

# %% [markdown]
# ## My approach(work in progress)
# ### Feature Engineering
#
# Here are my thoughts on feature engieering with my background knowledge on financial market.
#
#  - price_spread: the difference between ask price and bid price. Wide spread means low liquidity, leading to high volatility.
#  - volume: the sum of the ask/bid size. Low volume means low liquidity, leading to high volatility
#  - volume_imbalance: the difference between ask size and bid size. Large imbalance means low liquidity for one side, leading to high volatility
#
# Also, I created features only using last XX seconds to capture the dynamics of volatility further.
#
#
# ### Model Building
# - optimize the weight for RMSPE: see this discussion https://www.kaggle.com/c/optiver-realized-volatility-prediction/discussion/250324
# - one model for all stocks: model by stock_id does not work well. I am afraid of overfitting as well. stock_id is used as categorical and for target mean encoding.

# %% [markdown]
# ## Preparation

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
pd.set_option('max_rows', 300)
pd.set_option('max_columns', 300)

import os
import glob

# %%
# data directory
data_dir = 'data/'

# %% [markdown]
# ## Functions for preprocess

# %%
def calc_wap(df):
    wap = (df['bid_price1'] * df['ask_size1'] + df['ask_price1'] * df['bid_size1'])/(df['bid_size1'] + df['ask_size1'])
    return wap
def calc_wap2(df):
    wap = (df['bid_price2'] * df['ask_size2'] + df['ask_price2'] * df['bid_size2'])/(df['bid_size2'] + df['ask_size2'])
    return wap

# %%
def log_return(list_stock_prices):
    return np.log(list_stock_prices).diff()

# %%
def realized_volatility(series):
    return np.sqrt(np.sum(series**2))

# %%
def count_unique(series):
    return len(np.unique(series))

# %% [markdown]
# ## Main function for preprocessing book data

# %%
def preprocessor_book(file_path):
    df = pd.read_parquet(file_path)
    #calculate return etc
    df['wap'] = calc_wap(df)
    df['log_return'] = df.groupby('time_id')['wap'].apply(log_return)
    
    df['wap2'] = calc_wap2(df)
    df['log_return2'] = df.groupby('time_id')['wap2'].apply(log_return)
    
    df['wap_balance'] = abs(df['wap'] - df['wap2'])
    
    df['price_spread'] = (df['ask_price1'] - df['bid_price1']) / ((df['ask_price1'] + df['bid_price1'])/2)
    df['bid_spread'] = df['bid_price1'] - df['bid_price2']
    df['ask_spread'] = df['ask_price1'] - df['ask_price2']
    df['total_volume'] = (df['ask_size1'] + df['ask_size2']) + (df['bid_size1'] + df['bid_size2'])
    df['volume_imbalance'] = abs((df['ask_size1'] + df['ask_size2']) - (df['bid_size1'] + df['bid_size2']))

    # dict for aggregate
    create_feature_dict = {
        'log_return':[realized_volatility],
        'log_return2':[realized_volatility],
        'wap_balance':[np.mean],
        'price_spread':[np.mean],
        'bid_spread':[np.mean],
        'ask_spread':[np.mean],
        'volume_imbalance':[np.mean],
        'total_volume':[np.mean],
        'wap':[np.mean],
            }

    ##### groupby / all seconds
    df_feature = pd.DataFrame(df.groupby(['time_id']).agg(create_feature_dict)).reset_index()
    
    df_feature.columns = ['_'.join(col) for col in df_feature.columns] #time_id is changed to time_id_
        
    ###### groupby / last XX seconds
    last_seconds = [150, 300, 450]
    
    for second in last_seconds:
        second = 600 - second 
    
        df_feature_sec = pd.DataFrame(df.query(f'seconds_in_bucket >= {second}').groupby(['time_id']).agg(create_feature_dict)).reset_index()

        df_feature_sec.columns = ['_'.join(col) for col in df_feature_sec.columns] # time_id is changed to time_id_
     
        df_feature_sec = df_feature_sec.add_suffix('_' + str(second))

        df_feature = pd.merge(df_feature,df_feature_sec,how='left',left_on='time_id_',right_on=f'time_id__{second}')
        df_feature = df_feature.drop([f'time_id__{second}'],axis=1)
    
    # create row_id
    stock_id = file_path.split('=')[1]
    df_feature['row_id'] = df_feature['time_id_'].apply(lambda x:f'{stock_id}-{x}')
    df_feature = df_feature.drop(['time_id_'],axis=1)
    
    return df_feature

# %%
# %%time
file_path = data_dir + "book_train.parquet/stock_id=0"
preprocessor_book(file_path)
# Out:
# Wall time: 12 s
#       log_return_realized_volatility  log_return2_realized_volatility  \
# 0                           0.004499                         0.006999
# 1                           0.001204                         0.002476
# 2                           0.002369                         0.004801
# 3                           0.002574                         0.003637
# 4                           0.001894                         0.003257
# ...                              ...                              ...
# 3825                        0.002579                         0.003821
# 3826                        0.002206                         0.002847
# 3827                        0.002913                         0.003266
# 3828                        0.003046                         0.005105
# 3829                        0.001901                         0.002541
#
#       wap_balance_mean  price_spread_mean  bid_spread_mean  ask_spread_mean  \
# 0             0.000388           0.000852         0.000176        -0.000151
# 1             0.000212           0.000394         0.000142        -0.000135
# 2             0.000331           0.000725         0.000197        -0.000198
# 3             0.000380           0.000860         0.000190        -0.000108
# 4             0.000254           0.000397         0.000191        -0.000109
# ...                ...                ...              ...              ...
# 3825          0.000212           0.000552         0.000083        -0.000182
# 3826          0.000267           0.000542         0.000092        -0.000172
# 3827          0.000237           0.000525         0.000202        -0.000083
# 3828          0.000245           0.000480         0.000113        -0.000166
# 3829          0.000177           0.000458         0.000124        -0.000127
#
#       volume_imbalance_mean  total_volume_mean  wap_mean  \
# 0                134.894040         323.496689  1.003725
# 1                142.050000         411.450000  1.000239
# 2                141.414894         416.351064  0.999542
# 3                146.216667         435.266667  0.998832
# 4                123.846591         343.221591  0.999619
# ...                     ...                ...       ...
# 3825             197.144781         374.235690  0.997938
# 3826             233.781553         621.131068  1.000310
# 3827             115.829787         343.734043  0.999552
# 3828             132.074919         385.429967  1.002357
# 3829             165.754386         533.543860  0.999123
#
#       log_return_realized_volatility_400  log_return2_realized_volatility_400  \
# 0                               0.002300                             0.004589
# 1                               0.000934                             0.001907
# 2                               0.001179                             0.003034
# 3                               0.001003                             0.001513
# 4                               0.001434                             0.001516
# ...                                  ...                                  ...
# 3825                            0.001411                             0.002306
# 3826                            0.001288                             0.001866
# 3827                            0.001511                             0.002365
# 3828                            0.001617                             0.002919
# 3829                            0.001286                             0.001273
#
#       wap_balance_mean_400  price_spread_mean_400  bid_spread_mean_400  \
# 0                 0.000390               0.000783             0.000214
# 1                 0.000261               0.000367             0.000186
# 2                 0.000411               0.000625             0.000167
# 3                 0.000350               0.001050             0.000155
# 4                 0.000298               0.000469             0.000209
# ...                    ...                    ...                  ...
# 3825              0.000167               0.000447             0.000068
# 3826              0.000263               0.000555             0.000083
# 3827              0.000226               0.000470             0.000177
# 3828              0.000242               0.000503             0.000104
# 3829              0.000149               0.000412             0.000130
#
#       ask_spread_mean_400  volume_imbalance_mean_400  total_volume_mean_400  \
# 0               -0.000191                 124.326531             262.489796
# 1               -0.000133                  96.136986             480.000000
# 2               -0.000204                 152.509804             454.000000
# 3               -0.000048                 153.826087             498.956522
# 4               -0.000126                  85.618182             339.945455
# ...                   ...                        ...                    ...
# 3825            -0.000197                 220.857143             317.296703
# 3826            -0.000192                 250.672414             566.017241
# 3827            -0.000082                 109.246753             335.272727
# 3828            -0.000169                 115.728155             435.165049
# 3829            -0.000077                 136.594937             365.278481
#
#       wap_mean_400  log_return_realized_volatility_300  \
# 0         1.003633                            0.002953
# 1         1.000480                            0.000981
# 2         0.998356                            0.001295
# 3         0.998079                            0.001776
# 4         0.999473                            0.001520
# ...            ...                                 ...
# 3825      0.996927                            0.001673
# 3826      1.000753                            0.001487
# 3827      1.000220                            0.001928
# 3828      1.002305                            0.002137
# 3829      0.998501                            0.001507
#
#       log_return2_realized_volatility_300  wap_balance_mean_300  \
# 0                                0.004864              0.000372
# 1                                0.002009              0.000239
# 2                                0.003196              0.000431
# 3                                0.002713              0.000331
# 4                                0.002188              0.000252
# ...                                   ...                   ...
# 3825                             0.002573              0.000193
# 3826                             0.002255              0.000300
# 3827                             0.002646              0.000216
# 3828                             0.003934              0.000269
# 3829                             0.001517              0.000142
#
#       price_spread_mean_300  bid_spread_mean_300  ask_spread_mean_300  \
# 0                  0.000822             0.000223            -0.000162
# 1                  0.000353             0.000164            -0.000123
# 2                  0.000689             0.000141            -0.000249
# 3                  0.000833             0.000158            -0.000095
# 4                  0.000425             0.000191            -0.000120
# ...                     ...                  ...                  ...
# 3825               0.000509             0.000062            -0.000169
# 3826               0.000588             0.000074            -0.000177
# 3827               0.000446             0.000191            -0.000075
# 3828               0.000516             0.000096            -0.000175
# 3829               0.000432             0.000140            -0.000114
#
#       volume_imbalance_mean_300  total_volume_mean_300  wap_mean_300  \
# 0                    137.158273             294.928058      1.003753
# 1                    135.513043             484.521739      1.000397
# 2                    144.147059             455.235294      0.998685
# 3                    144.698113             418.169811      0.998436
# 4                     99.449438             407.584270      0.999488
# ...                         ...                    ...           ...
# 3825                 233.946667             350.560000      0.997519
# 3826                 257.920000             668.640000      1.000682
# 3827                 105.432692             326.759615      1.000111
# 3828                 123.423313             394.588957      1.002277
# 3829                 138.587719             460.429825      0.998454
#
#       log_return_realized_volatility_200  log_return2_realized_volatility_200  \
# 0                               0.003402                             0.005803
# 1                               0.001014                             0.002105
# 2                               0.001940                             0.003900
# 3                               0.001855                             0.002881
# 4                               0.001571                             0.002461
# ...                                  ...                                  ...
# 3825                            0.002247                             0.003328
# 3826                            0.001496                             0.002315
# 3827                            0.001963                             0.002842
# 3828                            0.002550                             0.004430
# 3829                            0.001642                             0.001721
#
#       wap_balance_mean_200  price_spread_mean_200  bid_spread_mean_200  \
# 0                 0.000379               0.000865             0.000205
# 1                 0.000210               0.000348             0.000139
# 2                 0.000396               0.000683             0.000146
# 3                 0.000339               0.000856             0.000133
# 4                 0.000230               0.000414             0.000174
# ...                    ...                    ...                  ...
# 3825              0.000223               0.000558             0.000067
# 3826              0.000293               0.000570             0.000082
# 3827              0.000223               0.000458             0.000213
# 3828              0.000269               0.000523             0.000093
# 3829              0.000150               0.000485             0.000134
#
#       ask_spread_mean_200  volume_imbalance_mean_200  total_volume_mean_200  \
# 0               -0.000155                 134.772021             321.455959
# 1               -0.000123                 151.407895             438.921053
# 2               -0.000263                 143.514851             440.544554
# 3               -0.000114                 137.217391             424.782609
# 4               -0.000108                 116.956140             388.394737
# ...                   ...                        ...                    ...
# 3825            -0.000176                 207.519608             341.882353
# 3826            -0.000180                 262.807407             694.985185
# 3827            -0.000072                 111.068966             318.155172
# 3828            -0.000153                 118.563107             387.029126
# 3829            -0.000118                 149.640288             495.438849
#
#       wap_mean_200   row_id
# 0         1.003836      0-5
# 1         1.000332     0-11
# 2         0.998944     0-16
# 3         0.998472     0-31
# 4         0.999575     0-62
# ...            ...      ...
# 3825      0.997725  0-32751
# 3826      1.000543  0-32753
# 3827      1.000001  0-32758
# 3828      1.002256  0-32763
# 3829      0.998584  0-32767
#
# [3830 rows x 37 columns]

# %%
trade_train = pd.read_parquet(data_dir + "trade_train.parquet/stock_id=0")
trade_train.head(15)
# Out:
#     time_id  seconds_in_bucket     price  size  order_count
# 0         5                 21  1.002301   326           12
# 1         5                 46  1.002778   128            4
# 2         5                 50  1.002818    55            1
# 3         5                 57  1.003155   121            5
# 4         5                 68  1.003646     4            1
# 5         5                 78  1.003762   134            5
# 6         5                122  1.004207   102            3
# 7         5                127  1.004577     1            1
# 8         5                144  1.004370     6            1
# 9         5                147  1.003964   233            4
# 10        5                177  1.003853     1            1
# 11        5                183  1.003956     2            1
# 12        5                187  1.004267   165            2
# 13        5                207  1.003543    72            4
# 14        5                218  1.004155    33            5

# %% [markdown]
# ## Main function for preprocessing trade data

# %%
def preprocessor_trade(file_path):
    df = pd.read_parquet(file_path)
    df['log_return'] = df.groupby('time_id')['price'].apply(log_return)
    
    
    aggregate_dictionary = {
        'log_return':[realized_volatility],
        'seconds_in_bucket':[count_unique],
        'size':[np.sum],
        'order_count':[np.mean],
    }
    
    df_feature = df.groupby('time_id').agg(aggregate_dictionary)
    
    df_feature = df_feature.reset_index()
    df_feature.columns = ['_'.join(col) for col in df_feature.columns]

    
    ######groupby / last XX seconds
    last_seconds = [150, 300, 450]
    
    for second in last_seconds:
        second = 600 - second
    
        df_feature_sec = df.query(f'seconds_in_bucket >= {second}').groupby('time_id').agg(aggregate_dictionary)
        df_feature_sec = df_feature_sec.reset_index()
        
        df_feature_sec.columns = ['_'.join(col) for col in df_feature_sec.columns]
        df_feature_sec = df_feature_sec.add_suffix('_' + str(second))
        
        df_feature = pd.merge(df_feature,df_feature_sec,how='left',left_on='time_id_',right_on=f'time_id__{second}')
        df_feature = df_feature.drop([f'time_id__{second}'],axis=1)
    
    df_feature = df_feature.add_prefix('trade_')
    stock_id = file_path.split('=')[1]
    df_feature['row_id'] = df_feature['trade_time_id_'].apply(lambda x:f'{stock_id}-{x}')
    df_feature = df_feature.drop(['trade_time_id_'],axis=1)
    
    return df_feature

# %%
# %%time
file_path = data_dir + "trade_train.parquet/stock_id=0"
preprocessor_trade(file_path)
# Out:
# Wall time: 5.79 s
#       trade_log_return_realized_volatility  \
# 0                                 0.002006
# 1                                 0.000901
# 2                                 0.001961
# 3                                 0.001561
# 4                                 0.000871
# ...                                    ...
# 3825                              0.001519
# 3826                              0.001411
# 3827                              0.001521
# 3828                              0.001794
# 3829                              0.001197
#
#       trade_seconds_in_bucket_count_unique  trade_size_sum  \
# 0                                       40            3179
# 1                                       30            1289
# 2                                       25            2161
# 3                                       15            1962
# 4                                       22            1791
# ...                                    ...             ...
# 3825                                    52            3450
# 3826                                    28            4547
# 3827                                    36            4250
# 3828                                    53            3217
# 3829                                    29            3679
#
#       trade_order_count_mean  trade_log_return_realized_volatility_400  \
# 0                   2.750000                                  0.001121
# 1                   1.900000                                  0.000510
# 2                   2.720000                                  0.001048
# 3                   3.933333                                  0.000802
# 4                   4.045455                                  0.000395
# ...                      ...                                       ...
# 3825                3.057692                                  0.000911
# 3826                3.892857                                  0.000765
# 3827                3.500000                                  0.000875
# 3828                2.150943                                  0.001070
# 3829                2.413793                                  0.000610
#
#       trade_seconds_in_bucket_count_unique_400  trade_size_sum_400  \
# 0                                         16.0              1045.0
# 1                                         11.0               829.0
# 2                                         10.0              1087.0
# 3                                          3.0               514.0
# 4                                          6.0               162.0
# ...                                        ...                 ...
# 3825                                      28.0              1856.0
# 3826                                       6.0              1401.0
# 3827                                      13.0              1149.0
# 3828                                      16.0              1463.0
# 3829                                      11.0              1820.0
#
#       trade_order_count_mean_400  trade_log_return_realized_volatility_300  \
# 0                       2.437500                                  0.001308
# 1                       2.090909                                  0.000587
# 2                       3.400000                                  0.001137
# 3                       3.666667                                  0.001089
# 4                       3.666667                                  0.000453
# ...                          ...                                       ...
# 3825                    3.142857                                  0.001162
# 3826                    5.166667                                  0.001066
# 3827                    2.692308                                  0.001242
# 3828                    2.312500                                  0.001404
# 3829                    2.909091                                  0.000801
#
#       trade_seconds_in_bucket_count_unique_300  trade_size_sum_300  \
# 0                                         21.0              1587.0
# 1                                         16.0               900.0
# 2                                         12.0              1189.0
# 3                                          9.0              1556.0
# 4                                         11.0              1219.0
# ...                                        ...                 ...
# 3825                                      35.0              2365.0
# 3826                                      12.0              2161.0
# 3827                                      22.0              2294.0
# 3828                                      25.0              1627.0
# 3829                                      16.0              2650.0
#
#       trade_order_count_mean_300  trade_log_return_realized_volatility_200  \
# 0                       2.571429                                  0.001666
# 1                       2.250000                                  0.000802
# 2                       3.166667                                  0.001575
# 3                       5.111111                                  0.001090
# 4                       4.909091                                  0.000498
# ...                          ...                                       ...
# 3825                    3.257143                                  0.001257
# 3826                    4.250000                                  0.001235
# 3827                    3.727273                                  0.001243
# 3828                    1.920000                                  0.001622
# 3829                    3.000000                                  0.000901
#
#       trade_seconds_in_bucket_count_unique_200  trade_size_sum_200  \
# 0                                         27.0              1901.0
# 1                                         22.0              1124.0
# 2                                         18.0              1691.0
# 3                                         10.0              1561.0
# 4                                         14.0              1458.0
# ...                                        ...                 ...
# 3825                                      39.0              2407.0
# 3826                                      18.0              2493.0
# 3827                                      23.0              2295.0
# 3828                                      33.0              2171.0
# 3829                                      18.0              2851.0
#
#       trade_order_count_mean_200   row_id
# 0                       2.555556      0-5
# 1                       2.045455     0-11
# 2                       2.833333     0-16
# 3                       4.700000     0-31
# 4                       4.428571     0-62
# ...                          ...      ...
# 3825                    3.128205  0-32751
# 3826                    3.555556  0-32753
# 3827                    3.608696  0-32758
# 3828                    2.030303  0-32763
# 3829                    2.833333  0-32767
#
# [3830 rows x 17 columns]

# %% [markdown]
# ## Combined preprocessor function

# %%
def preprocessor(list_stock_ids, is_train = True):
    from joblib import Parallel, delayed # parallel computing to save time
    df = pd.DataFrame()
    
    def for_joblib(stock_id):
        if is_train:
            file_path_book = data_dir + "book_train.parquet/stock_id=" + str(stock_id)
            file_path_trade = data_dir + "trade_train.parquet/stock_id=" + str(stock_id)
        else:
            file_path_book = data_dir + "book_test.parquet/stock_id=" + str(stock_id)
            file_path_trade = data_dir + "trade_test.parquet/stock_id=" + str(stock_id)
            
        df_tmp = pd.merge(preprocessor_book(file_path_book),preprocessor_trade(file_path_trade),on='row_id',how='left')
     
        return pd.concat([df,df_tmp])
    
    df = Parallel(n_jobs=-1, verbose=1)(
        delayed(for_joblib)(stock_id) for stock_id in list_stock_ids
        )

    df =  pd.concat(df,ignore_index = True)
    return df

# %%
list_stock_ids = [0,1]
preprocessor(list_stock_ids, is_train = True)
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of   2 | elapsed:   23.0s finished
#       log_return_realized_volatility  log_return2_realized_volatility  \
# 0                           0.004499                         0.006999
# 1                           0.001204                         0.002476
# 2                           0.002369                         0.004801
# 3                           0.002574                         0.003637
# 4                           0.001894                         0.003257
# ...                              ...                              ...
# 7655                        0.003723                         0.004996
# 7656                        0.010829                         0.012168
# 7657                        0.003135                         0.004268
# 7658                        0.003750                         0.005773
# 7659                        0.001681                         0.002399
#
#       wap_balance_mean  price_spread_mean  bid_spread_mean  ask_spread_mean  \
# 0             0.000388           0.000852         0.000176        -0.000151
# 1             0.000212           0.000394         0.000142        -0.000135
# 2             0.000331           0.000725         0.000197        -0.000198
# 3             0.000380           0.000860         0.000190        -0.000108
# 4             0.000254           0.000397         0.000191        -0.000109
# ...                ...                ...              ...              ...
# 7655          0.000330           0.000597         0.000157        -0.000118
# 7656          0.000403           0.000922         0.000159        -0.000125
# 7657          0.000243           0.000648         0.000141        -0.000132
# 7658          0.000199           0.000421         0.000190        -0.000231
# 7659          0.000104           0.000281         0.000121        -0.000121
#
#       volume_imbalance_mean  total_volume_mean  wap_mean  \
# 0                134.894040         323.496689  1.003725
# 1                142.050000         411.450000  1.000239
# 2                141.414894         416.351064  0.999542
# 3                146.216667         435.266667  0.998832
# 4                123.846591         343.221591  0.999619
# ...                     ...                ...       ...
# 7655             125.013029         296.185668  1.000142
# 7656             254.006073         567.840081  1.007503
# 7657             163.645367         426.603834  1.000854
# 7658             138.235023         526.317972  1.003032
# 7659             175.268852         713.537705  1.000060
#
#       log_return_realized_volatility_400  log_return2_realized_volatility_400  \
# 0                               0.002300                             0.004589
# 1                               0.000934                             0.001907
# 2                               0.001179                             0.003034
# 3                               0.001003                             0.001513
# 4                               0.001434                             0.001516
# ...                                  ...                                  ...
# 7655                            0.001584                             0.001957
# 7656                            0.006736                             0.007670
# 7657                            0.001737                             0.002177
# 7658                            0.002287                             0.003912
# 7659                            0.000952                             0.001433
#
#       wap_balance_mean_400  price_spread_mean_400  bid_spread_mean_400  \
# 0                 0.000390               0.000783             0.000214
# 1                 0.000261               0.000367             0.000186
# 2                 0.000411               0.000625             0.000167
# 3                 0.000350               0.001050             0.000155
# 4                 0.000298               0.000469             0.000209
# ...                    ...                    ...                  ...
# 7655              0.000268               0.000605             0.000169
# 7656              0.000511               0.001110             0.000222
# 7657              0.000279               0.000634             0.000132
# 7658              0.000209               0.000394             0.000166
# 7659              0.000111               0.000287             0.000113
#
#       ask_spread_mean_400  volume_imbalance_mean_400  total_volume_mean_400  \
# 0               -0.000191                 124.326531             262.489796
# 1               -0.000133                  96.136986             480.000000
# 2               -0.000204                 152.509804             454.000000
# 3               -0.000048                 153.826087             498.956522
# 4               -0.000126                  85.618182             339.945455
# ...                   ...                        ...                    ...
# 7655            -0.000100                 132.111111             359.691358
# 7656            -0.000113                 235.212500             527.625000
# 7657            -0.000146                 131.526882             433.182796
# 7658            -0.000235                 155.471831             526.260563
# 7659            -0.000125                 202.824074             709.509259
#
#       wap_mean_400  log_return_realized_volatility_300  \
# 0         1.003633                            0.002953
# 1         1.000480                            0.000981
# 2         0.998356                            0.001295
# 3         0.998079                            0.001776
# 4         0.999473                            0.001520
# ...            ...                                 ...
# 7655      1.000157                            0.002212
# 7656      1.011841                            0.008499
# 7657      1.001216                            0.002108
# 7658      1.004099                            0.002728
# 7659      0.999973                            0.001190
#
#       log_return2_realized_volatility_300  wap_balance_mean_300  \
# 0                                0.004864              0.000372
# 1                                0.002009              0.000239
# 2                                0.003196              0.000431
# 3                                0.002713              0.000331
# 4                                0.002188              0.000252
# ...                                   ...                   ...
# 7655                             0.002954              0.000283
# 7656                             0.009971              0.000483
# 7657                             0.003184              0.000261
# 7658                             0.004435              0.000195
# 7659                             0.001566              0.000110
#
#       price_spread_mean_300  bid_spread_mean_300  ask_spread_mean_300  \
# 0                  0.000822             0.000223            -0.000162
# 1                  0.000353             0.000164            -0.000123
# 2                  0.000689             0.000141            -0.000249
# 3                  0.000833             0.000158            -0.000095
# 4                  0.000425             0.000191            -0.000120
# ...                     ...                  ...                  ...
# 7655               0.000617             0.000165            -0.000104
# 7656               0.001082             0.000196            -0.000129
# 7657               0.000625             0.000146            -0.000146
# 7658               0.000410             0.000165            -0.000240
# 7659               0.000292             0.000113            -0.000118
#
#       volume_imbalance_mean_300  total_volume_mean_300  wap_mean_300  \
# 0                    137.158273             294.928058      1.003753
# 1                    135.513043             484.521739      1.000397
# 2                    144.147059             455.235294      0.998685
# 3                    144.698113             418.169811      0.998436
# 4                     99.449438             407.584270      0.999488
# ...                         ...                    ...           ...
# 7655                 120.469231             322.284615      1.000130
# 7656                 217.410788             485.195021      1.012343
# 7657                 142.402685             426.939597      1.001250
# 7658                 148.273543             519.044843      1.004296
# 7659                 183.513158             709.894737      1.000165
#
#       log_return_realized_volatility_200  log_return2_realized_volatility_200  \
# 0                               0.003402                             0.005803
# 1                               0.001014                             0.002105
# 2                               0.001940                             0.003900
# 3                               0.001855                             0.002881
# 4                               0.001571                             0.002461
# ...                                  ...                                  ...
# 7655                            0.002973                             0.003814
# 7656                            0.009946                             0.011071
# 7657                            0.002363                             0.003635
# 7658                            0.003087                             0.005227
# 7659                            0.001426                             0.001778
#
#       wap_balance_mean_200  price_spread_mean_200  bid_spread_mean_200  \
# 0                 0.000379               0.000865             0.000205
# 1                 0.000210               0.000348             0.000139
# 2                 0.000396               0.000683             0.000146
# 3                 0.000339               0.000856             0.000133
# 4                 0.000230               0.000414             0.000174
# ...                    ...                    ...                  ...
# 7655              0.000277               0.000608             0.000152
# 7656              0.000468               0.001037             0.000177
# 7657              0.000258               0.000620             0.000143
# 7658              0.000200               0.000439             0.000180
# 7659              0.000108               0.000278             0.000111
#
#       ask_spread_mean_200  volume_imbalance_mean_200  total_volume_mean_200  \
# 0               -0.000155                 134.772021             321.455959
# 1               -0.000123                 151.407895             438.921053
# 2               -0.000263                 143.514851             440.544554
# 3               -0.000114                 137.217391             424.782609
# 4               -0.000108                 116.956140             388.394737
# ...                   ...                        ...                    ...
# 7655            -0.000121                 129.730964             291.416244
# 7656            -0.000131                 229.679128             513.903427
# 7657            -0.000138                 154.732719             404.843318
# 7658            -0.000239                 130.053872             524.074074
# 7659            -0.000115                 188.054187             706.320197
#
#       wap_mean_200   row_id  trade_log_return_realized_volatility  \
# 0         1.003836      0-5                              0.002006
# 1         1.000332     0-11                              0.000901
# 2         0.998944     0-16                              0.001961
# 3         0.998472     0-31                              0.001561
# 4         0.999575     0-62                              0.000871
# ...            ...      ...                                   ...
# 7655      1.000000  1-32751                              0.001776
# 7656      1.011773  1-32753                              0.008492
# 7657      1.001174  1-32758                              0.001927
# 7658      1.004028  1-32763                              0.002856
# 7659      1.000132  1-32767                              0.001704
#
#       trade_seconds_in_bucket_count_unique  trade_size_sum  \
# 0                                       40            3179
# 1                                       30            1289
# 2                                       25            2161
# 3                                       15            1962
# 4                                       22            1791
# ...                                    ...             ...
# 7655                                    49            3249
# 7656                                   183           75903
# 7657                                    26            2239
# 7658                                   109           16648
# 7659                                    82            7478
#
#       trade_order_count_mean  trade_log_return_realized_volatility_400  \
# 0                   2.750000                                  0.001121
# 1                   1.900000                                  0.000510
# 2                   2.720000                                  0.001048
# 3                   3.933333                                  0.000802
# 4                   4.045455                                  0.000395
# ...                      ...                                       ...
# 7655                2.775510                                  0.001028
# 7656                7.874317                                  0.003885
# 7657                2.615385                                  0.001355
# 7658                2.935780                                  0.001684
# 7659                2.073171                                  0.000987
#
#       trade_seconds_in_bucket_count_unique_400  trade_size_sum_400  \
# 0                                         16.0              1045.0
# 1                                         11.0               829.0
# 2                                         10.0              1087.0
# 3                                          3.0               514.0
# 4                                          6.0               162.0
# ...                                        ...                 ...
# 7655                                      16.0              1532.0
# 7656                                      51.0             19713.0
# 7657                                       7.0               654.0
# 7658                                      37.0              5279.0
# 7659                                      29.0              2380.0
#
#       trade_order_count_mean_400  trade_log_return_realized_volatility_300  \
# 0                       2.437500                                  0.001308
# 1                       2.090909                                  0.000587
# 2                       3.400000                                  0.001137
# 3                       3.666667                                  0.001089
# 4                       3.666667                                  0.000453
# ...                          ...                                       ...
# 7655                    3.937500                                  0.001280
# 7656                    6.862745                                  0.006310
# 7657                    2.714286                                  0.001567
# 7658                    2.837838                                  0.001919
# 7659                    2.172414                                  0.001303
#
#       trade_seconds_in_bucket_count_unique_300  trade_size_sum_300  \
# 0                                         21.0              1587.0
# 1                                         16.0               900.0
# 2                                         12.0              1189.0
# 3                                          9.0              1556.0
# 4                                         11.0              1219.0
# ...                                        ...                 ...
# 7655                                      23.0              1889.0
# 7656                                      88.0             30858.0
# 7657                                      11.0               980.0
# 7658                                      57.0              8274.0
# 7659                                      40.0              3505.0
#
#       trade_order_count_mean_300  trade_log_return_realized_volatility_200  \
# 0                       2.571429                                  0.001666
# 1                       2.250000                                  0.000802
# 2                       3.166667                                  0.001575
# 3                       5.111111                                  0.001090
# 4                       4.909091                                  0.000498
# ...                          ...                                       ...
# 7655                    3.608696                                  0.001462
# 7656                    8.136364                                  0.007641
# 7657                    2.727273                                  0.001692
# 7658                    2.701754                                  0.002478
# 7659                    2.125000                                  0.001444
#
#       trade_seconds_in_bucket_count_unique_200  trade_size_sum_200  \
# 0                                         27.0              1901.0
# 1                                         22.0              1124.0
# 2                                         18.0              1691.0
# 3                                         10.0              1561.0
# 4                                         14.0              1458.0
# ...                                        ...                 ...
# 7655                                      31.0              2290.0
# 7656                                     126.0             49265.0
# 7657                                      20.0              1734.0
# 7658                                      76.0             10960.0
# 7659                                      53.0              4684.0
#
#       trade_order_count_mean_200
# 0                       2.555556
# 1                       2.045455
# 2                       2.833333
# 3                       4.700000
# 4                       4.428571
# ...                          ...
# 7655                    3.129032
# 7656                    8.293651
# 7657                    2.700000
# 7658                    2.710526
# 7659                    2.056604
#
# [7660 rows x 53 columns]

# %% [markdown]
# ## Training set

# %%
train = pd.read_csv(data_dir + 'train.csv')

# %%
train_ids = train.stock_id.unique()

# %%
# %%time
df_train = preprocessor(list_stock_ids= train_ids, is_train = True)
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  26 tasks      | elapsed:  1.7min
# C:\Users\yzho0040\Anaconda3\lib\site-packages\joblib\externals\loky\process_executor.py:688: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# [Parallel(n_jobs=-1)]: Done 112 out of 112 | elapsed:  6.1min finished
# Wall time: 6min 6s

# %%
train['row_id'] = train['stock_id'].astype(str) + '-' + train['time_id'].astype(str)
train = train[['row_id','target']]
df_train = train.merge(df_train, on = ['row_id'], how = 'left')

# %%
df_train.to_csv('train_data.csv')

# %% [markdown]
# ## Test set

# %%
test = pd.read_csv(data_dir + 'test.csv')

# %%
test_ids = test.stock_id.unique()

# %%
# %%time
df_test = preprocessor(list_stock_ids= test_ids, is_train = False)
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# Wall time: 363 ms
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:    0.3s finished

# %%
df_test = test.merge(df_test, on = ['row_id'], how = 'left')

# %%
df_test.to_csv('data/test_data.csv')

# %% [markdown]
# ## Target encoding by stock_id

# %%
df_train = pd.read_csv('data/train_data.csv', index_col=0)
df_test = pd.read_csv('data/test_data.csv', index_col=0)

# %%
from sklearn.model_selection import KFold
#stock_id target encoding
df_train['stock_id'] = df_train['row_id'].apply(lambda x:x.split('-')[0])
df_test['stock_id'] = df_test['row_id'].apply(lambda x:x.split('-')[0])

stock_id_target_mean = df_train.groupby('stock_id')['target'].mean() 
df_test['stock_id_target_enc'] = df_test['stock_id'].map(stock_id_target_mean) # test_set

#training
tmp = np.repeat(np.nan, df_train.shape[0])
kf = KFold(n_splits = 10, shuffle=True,random_state = 19911109)
for idx_1, idx_2 in kf.split(df_train):
    target_mean = df_train.iloc[idx_1].groupby('stock_id')['target'].mean()

    tmp[idx_2] = df_train['stock_id'].iloc[idx_2].map(target_mean)
df_train['stock_id_target_enc'] = tmp

# %% [markdown]
# ## Model Building

# %%
df_train.head()
# Out:
#   row_id    target  log_return_realized_volatility  \
# 0    0-5  0.004136                        0.004499
# 1   0-11  0.001445                        0.001204
# 2   0-16  0.002168                        0.002369
# 3   0-31  0.002195                        0.002574
# 4   0-62  0.001747                        0.001894
#
#    log_return2_realized_volatility  wap_balance_mean  price_spread_mean  \
# 0                         0.006999          0.000388           0.000852
# 1                         0.002476          0.000212           0.000394
# 2                         0.004801          0.000331           0.000725
# 3                         0.003637          0.000380           0.000860
# 4                         0.003257          0.000254           0.000397
#
#    bid_spread_mean  ask_spread_mean  volume_imbalance_mean  total_volume_mean  \
# 0         0.000176        -0.000151             134.894040         323.496689
# 1         0.000142        -0.000135             142.050000         411.450000
# 2         0.000197        -0.000198             141.414894         416.351064
# 3         0.000190        -0.000108             146.216667         435.266667
# 4         0.000191        -0.000109             123.846591         343.221591
#
#    wap_mean  log_return_realized_volatility_400  \
# 0  1.003725                            0.002300
# 1  1.000239                            0.000934
# 2  0.999542                            0.001179
# 3  0.998831                            0.001003
# 4  0.999619                            0.001434
#
#    log_return2_realized_volatility_400  wap_balance_mean_400  \
# 0                             0.004589              0.000390
# 1                             0.001907              0.000261
# 2                             0.003034              0.000411
# 3                             0.001513              0.000350
# 4                             0.001516              0.000298
#
#    price_spread_mean_400  bid_spread_mean_400  ask_spread_mean_400  \
# 0               0.000783             0.000214            -0.000191
# 1               0.000367             0.000186            -0.000133
# 2               0.000625             0.000167            -0.000204
# 3               0.001050             0.000155            -0.000048
# 4               0.000469             0.000209            -0.000126
#
#    volume_imbalance_mean_400  total_volume_mean_400  wap_mean_400  \
# 0                 124.326531             262.489796      1.003633
# 1                  96.136986             480.000000      1.000480
# 2                 152.509804             454.000000      0.998356
# 3                 153.826087             498.956522      0.998079
# 4                  85.618182             339.945455      0.999473
#
#    log_return_realized_volatility_300  log_return2_realized_volatility_300  \
# 0                            0.002953                             0.004864
# 1                            0.000981                             0.002009
# 2                            0.001295                             0.003196
# 3                            0.001776                             0.002713
# 4                            0.001520                             0.002188
#
#    wap_balance_mean_300  price_spread_mean_300  bid_spread_mean_300  \
# 0              0.000372               0.000822             0.000223
# 1              0.000239               0.000353             0.000164
# 2              0.000431               0.000689             0.000141
# 3              0.000331               0.000833             0.000158
# 4              0.000252               0.000425             0.000191
#
#    ask_spread_mean_300  volume_imbalance_mean_300  total_volume_mean_300  \
# 0            -0.000162                 137.158273             294.928058
# 1            -0.000123                 135.513043             484.521739
# 2            -0.000249                 144.147059             455.235294
# 3            -0.000095                 144.698113             418.169811
# 4            -0.000120                  99.449438             407.584270
#
#    wap_mean_300  log_return_realized_volatility_200  \
# 0      1.003753                            0.003402
# 1      1.000397                            0.001014
# 2      0.998685                            0.001940
# 3      0.998436                            0.001855
# 4      0.999488                            0.001571
#
#    log_return2_realized_volatility_200  wap_balance_mean_200  \
# 0                             0.005803              0.000379
# 1                             0.002105              0.000210
# 2                             0.003900              0.000396
# 3                             0.002881              0.000339
# 4                             0.002461              0.000230
#
#    price_spread_mean_200  bid_spread_mean_200  ask_spread_mean_200  \
# 0               0.000865             0.000205            -0.000155
# 1               0.000348             0.000139            -0.000123
# 2               0.000683             0.000146            -0.000263
# 3               0.000856             0.000133            -0.000114
# 4               0.000414             0.000174            -0.000108
#
#    volume_imbalance_mean_200  total_volume_mean_200  wap_mean_200  \
# 0                 134.772021             321.455959      1.003836
# 1                 151.407895             438.921053      1.000332
# 2                 143.514851             440.544554      0.998943
# 3                 137.217391             424.782609      0.998472
# 4                 116.956140             388.394737      0.999575
#
#    trade_log_return_realized_volatility  trade_seconds_in_bucket_count_unique  \
# 0                              0.002006                                  40.0
# 1                              0.000901                                  30.0
# 2                              0.001961                                  25.0
# 3                              0.001561                                  15.0
# 4                              0.000871                                  22.0
#
#    trade_size_sum  trade_order_count_mean  \
# 0          3179.0                2.750000
# 1          1289.0                1.900000
# 2          2161.0                2.720000
# 3          1962.0                3.933333
# 4          1791.0                4.045455
#
#    trade_log_return_realized_volatility_400  \
# 0                                  0.001121
# 1                                  0.000510
# 2                                  0.001048
# 3                                  0.000802
# 4                                  0.000395
#
#    trade_seconds_in_bucket_count_unique_400  trade_size_sum_400  \
# 0                                      16.0              1045.0
# 1                                      11.0               829.0
# 2                                      10.0              1087.0
# 3                                       3.0               514.0
# 4                                       6.0               162.0
#
#    trade_order_count_mean_400  trade_log_return_realized_volatility_300  \
# 0                    2.437500                                  0.001308
# 1                    2.090909                                  0.000587
# 2                    3.400000                                  0.001137
# 3                    3.666667                                  0.001089
# 4                    3.666667                                  0.000453
#
#    trade_seconds_in_bucket_count_unique_300  trade_size_sum_300  \
# 0                                      21.0              1587.0
# 1                                      16.0               900.0
# 2                                      12.0              1189.0
# 3                                       9.0              1556.0
# 4                                      11.0              1219.0
#
#    trade_order_count_mean_300  trade_log_return_realized_volatility_200  \
# 0                    2.571429                                  0.001666
# 1                    2.250000                                  0.000802
# 2                    3.166667                                  0.001575
# 3                    5.111111                                  0.001090
# 4                    4.909091                                  0.000498
#
#    trade_seconds_in_bucket_count_unique_200  trade_size_sum_200  \
# 0                                      27.0              1901.0
# 1                                      22.0              1124.0
# 2                                      18.0              1691.0
# 3                                      10.0              1561.0
# 4                                      14.0              1458.0
#
#    trade_order_count_mean_200 stock_id  stock_id_target_enc
# 0                    2.555556        0             0.004041
# 1                    2.045455        0             0.004039
# 2                    2.833333        0             0.004041
# 3                    4.700000        0             0.004013
# 4                    4.428571        0             0.004032

# %%
df_test.head()
# Out:
#   stock_id  time_id row_id  log_return_realized_volatility  \
# 0        0        4    0-4                        0.000294
# 1        0       32   0-32                             NaN
# 2        0       34   0-34                             NaN
#
#    log_return2_realized_volatility  wap_balance_mean  price_spread_mean  \
# 0                         0.000252          0.000145           0.000557
# 1                              NaN               NaN                NaN
# 2                              NaN               NaN                NaN
#
#    bid_spread_mean  ask_spread_mean  volume_imbalance_mean  total_volume_mean  \
# 0         0.000393        -0.000115             164.666667         350.666667
# 1              NaN              NaN                    NaN                NaN
# 2              NaN              NaN                    NaN                NaN
#
#    wap_mean  log_return_realized_volatility_400  \
# 0  1.000405                                 NaN
# 1       NaN                                 NaN
# 2       NaN                                 NaN
#
#    log_return2_realized_volatility_400  wap_balance_mean_400  \
# 0                                  NaN                   NaN
# 1                                  NaN                   NaN
# 2                                  NaN                   NaN
#
#    price_spread_mean_400  bid_spread_mean_400  ask_spread_mean_400  \
# 0                    NaN                  NaN                  NaN
# 1                    NaN                  NaN                  NaN
# 2                    NaN                  NaN                  NaN
#
#    volume_imbalance_mean_400  total_volume_mean_400  wap_mean_400  \
# 0                        NaN                    NaN           NaN
# 1                        NaN                    NaN           NaN
# 2                        NaN                    NaN           NaN
#
#    log_return_realized_volatility_300  log_return2_realized_volatility_300  \
# 0                                 NaN                                  NaN
# 1                                 NaN                                  NaN
# 2                                 NaN                                  NaN
#
#    wap_balance_mean_300  price_spread_mean_300  bid_spread_mean_300  \
# 0                   NaN                    NaN                  NaN
# 1                   NaN                    NaN                  NaN
# 2                   NaN                    NaN                  NaN
#
#    ask_spread_mean_300  volume_imbalance_mean_300  total_volume_mean_300  \
# 0                  NaN                        NaN                    NaN
# 1                  NaN                        NaN                    NaN
# 2                  NaN                        NaN                    NaN
#
#    wap_mean_300  log_return_realized_volatility_200  \
# 0           NaN                                 NaN
# 1           NaN                                 NaN
# 2           NaN                                 NaN
#
#    log_return2_realized_volatility_200  wap_balance_mean_200  \
# 0                                  NaN                   NaN
# 1                                  NaN                   NaN
# 2                                  NaN                   NaN
#
#    price_spread_mean_200  bid_spread_mean_200  ask_spread_mean_200  \
# 0                    NaN                  NaN                  NaN
# 1                    NaN                  NaN                  NaN
# 2                    NaN                  NaN                  NaN
#
#    volume_imbalance_mean_200  total_volume_mean_200  wap_mean_200  \
# 0                        NaN                    NaN           NaN
# 1                        NaN                    NaN           NaN
# 2                        NaN                    NaN           NaN
#
#    trade_log_return_realized_volatility  trade_seconds_in_bucket_count_unique  \
# 0                              0.000295                                   3.0
# 1                                   NaN                                   NaN
# 2                                   NaN                                   NaN
#
#    trade_size_sum  trade_order_count_mean  \
# 0           201.0                3.666667
# 1             NaN                     NaN
# 2             NaN                     NaN
#
#    trade_log_return_realized_volatility_400  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
#
#    trade_seconds_in_bucket_count_unique_400  trade_size_sum_400  \
# 0                                       NaN                 NaN
# 1                                       NaN                 NaN
# 2                                       NaN                 NaN
#
#    trade_order_count_mean_400  trade_log_return_realized_volatility_300  \
# 0                         NaN                                       NaN
# 1                         NaN                                       NaN
# 2                         NaN                                       NaN
#
#    trade_seconds_in_bucket_count_unique_300  trade_size_sum_300  \
# 0                                       NaN                 NaN
# 1                                       NaN                 NaN
# 2                                       NaN                 NaN
#
#    trade_order_count_mean_300  trade_log_return_realized_volatility_200  \
# 0                         NaN                                       NaN
# 1                         NaN                                       NaN
# 2                         NaN                                       NaN
#
#    trade_seconds_in_bucket_count_unique_200  trade_size_sum_200  \
# 0                                       NaN                 NaN
# 1                                       NaN                 NaN
# 2                                       NaN                 NaN
#
#    trade_order_count_mean_200  stock_id_target_enc
# 0                         NaN             0.004028
# 1                         NaN             0.004028
# 2                         NaN             0.004028

# %% [markdown]
# ## LightGBM

# %%
import lightgbm as lgbm
from bayes_opt import BayesianOptimization

# %%
df_train['stock_id'] = df_train['stock_id'].astype(int)
df_test['stock_id'] = df_test['stock_id'].astype(int)

# %%
X = df_train.drop(['row_id','target'],axis=1)
y = df_train['target']

# %%
def rmspe(y_true, y_pred):
    return  (np.sqrt(np.mean(np.square((y_true - y_pred) / y_true))))

def feval_RMSPE(preds, lgbm_train):
    labels = lgbm_train.get_label()
    return 'RMSPE', round(rmspe(y_true = labels, y_pred = preds),5), False

# %%
def bayes_parameter_opt_lgb(X, y, init_round=15, opt_round=25, n_folds=3, random_seed=6,n_estimators=10000, output_process=False):
    def lgb_eval(learning_rate,num_leaves, feature_fraction, bagging_fraction, max_depth, max_bin, min_data_in_leaf,min_sum_hessian_in_leaf,subsample):
        params = {'application':'regression', 'metric':'RMSPE'}
        params['learning_rate'] = max(min(learning_rate, 1), 0)
        params["num_leaves"] = int(round(num_leaves))
        params['feature_fraction'] = max(min(feature_fraction, 1), 0)
        params['bagging_fraction'] = max(min(bagging_fraction, 1), 0)
        params['max_depth'] = int(round(max_depth))
        params['max_bin'] = int(round(max_depth))
        params['min_data_in_leaf'] = int(round(min_data_in_leaf))
        params['min_sum_hessian_in_leaf'] = min_sum_hessian_in_leaf
        params['subsample'] = max(min(subsample, 1), 0)
        
        scores = 0.0
        
        for fold, (trn_idx, val_idx) in enumerate(kf.split(X, y)):
            X_train, y_train = X.loc[trn_idx], y[trn_idx]
            X_valid, y_valid = X.loc[val_idx], y[val_idx]
            
            weights = 1/np.square(y_train)
            lgbm_train = lgbm.Dataset(X_train,y_train,weight = weights)

            weights = 1/np.square(y_valid)
            lgbm_valid = lgbm.Dataset(X_valid,y_valid,reference = lgbm_train,weight = weights)
            
            model = lgbm.train(params=params,
                      train_set=lgbm_train,
                      valid_sets=[lgbm_train, lgbm_valid],
                      num_boost_round=5000,         
                      feval=feval_RMSPE,
                      verbose_eval=100,
                      categorical_feature = ['stock_id']                
                     )
            y_pred = model.predict(X_valid, num_iteration=model.best_iteration)

            RMSPE = round(rmspe(y_true = y_valid, y_pred = y_pred),3)
#             print(f'Performance of the　prediction: , RMSPE: {RMSPE}')

            #keep scores and models
            scores += RMSPE / 5
        return scores
     
    lgbBO = BayesianOptimization(lgb_eval, {'learning_rate': (0.01, 1.0),
                                            'num_leaves': (24, 80),
                                            'feature_fraction': (0.1, 0.9),
                                            'bagging_fraction': (0.2, 1),
                                            'max_depth': (5, 500),
                                            'max_bin':(20,200),
                                            'min_data_in_leaf': (20, 200),
                                            'min_sum_hessian_in_leaf':(0,100),
                                           'subsample': (0.01, 1.0)}, random_state=200)

    lgbBO.maximize(init_points=init_round, n_iter=opt_round)
    
    model_auc=[]
    for model in range(len(lgbBO.res)):
        model_auc.append(lgbBO.res[model]['target'])
    
    # return best parameters
    return lgbBO.res[pd.Series(model_auc).idxmax()]['target'],lgbBO.res[pd.Series(model_auc).idxmax()]['params']

# %%
opt_params = bayes_parameter_opt_lgb(X, y, init_round=5, opt_round=10, n_folds=3, random_seed=6,n_estimators=100)
# Out:
# |   iter    |  target   | baggin... | featur... | learni... |  max_bin  | max_depth | min_da... | min_su... | num_le... | subsample |
# -------------------------------------------------------------------------------------------------------------------------------------
# C:\Users\yzho0040\Anaconda3\lib\site-packages\lightgbm\basic.py:1705: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is ['stock_id']
#   _log_warning('categorical_feature in Dataset is overridden.\n'
# [LightGBM] [Warning] bagging_fraction is set=0.9581058054813363, subsample=0.4615201756036703 will be ignored. Current value: bagging_fraction=0.9581058054813363
# [LightGBM] [Warning] bagging_fraction is set=0.9581058054813363, subsample=0.4615201756036703 will be ignored. Current value: bagging_fraction=0.9581058054813363
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.364680 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 20145
# [LightGBM] [Info] Number of data points in the train set: 343145, number of used features: 54
# [LightGBM] [Warning] bagging_fraction is set=0.9581058054813363, subsample=0.4615201756036703 will be ignored. Current value: bagging_fraction=0.9581058054813363
# C:\Users\yzho0040\Anaconda3\lib\site-packages\lightgbm\basic.py:1433: UserWarning: Overriding the parameters from Reference Dataset.
#   _log_warning('Overriding the parameters from Reference Dataset.')
# C:\Users\yzho0040\Anaconda3\lib\site-packages\lightgbm\basic.py:1245: UserWarning: categorical_column in param dict is overridden.
#   _log_warning('{} in param dict is overridden.'.format(cat_alias))
# [LightGBM] [Info] Start training from score 0.001800
# [100]	training's RMSPE: 0.20456	valid_1's RMSPE: 0.24535
# [200]	training's RMSPE: 0.18984	valid_1's RMSPE: 0.25101
# [300]	training's RMSPE: 0.17747	valid_1's RMSPE: 0.2561
# [400]	training's RMSPE: 0.16746	valid_1's RMSPE: 0.26078
# [500]	training's RMSPE: 0.15831	valid_1's RMSPE: 0.26412
# [600]	training's RMSPE: 0.15015	valid_1's RMSPE: 0.26754
# [700]	training's RMSPE: 0.14276	valid_1's RMSPE: 0.27
# [800]	training's RMSPE: 0.13601	valid_1's RMSPE: 0.27222
# [900]	training's RMSPE: 0.12963	valid_1's RMSPE: 0.27429
# [1000]	training's RMSPE: 0.1238	valid_1's RMSPE: 0.27658
# [1100]	training's RMSPE: 0.11802	valid_1's RMSPE: 0.27854
# [1200]	training's RMSPE: 0.11315	valid_1's RMSPE: 0.28003
# [1300]	training's RMSPE: 0.1083	valid_1's RMSPE: 0.28199
# [1400]	training's RMSPE: 0.10391	valid_1's RMSPE: 0.28279
# [1500]	training's RMSPE: 0.09978	valid_1's RMSPE: 0.28417
# [1600]	training's RMSPE: 0.09563	valid_1's RMSPE: 0.28537
# [1700]	training's RMSPE: 0.09179	valid_1's RMSPE: 0.28654
# [1800]	training's RMSPE: 0.08843	valid_1's RMSPE: 0.28768
# [1900]	training's RMSPE: 0.08512	valid_1's RMSPE: 0.28842
# [2000]	training's RMSPE: 0.08195	valid_1's RMSPE: 0.28919
# [2100]	training's RMSPE: 0.07892	valid_1's RMSPE: 0.2902
# [2200]	training's RMSPE: 0.07584	valid_1's RMSPE: 0.29106
# [2300]	training's RMSPE: 0.07302	valid_1's RMSPE: 0.29176
# [2400]	training's RMSPE: 0.07045	valid_1's RMSPE: 0.29249
# [2500]	training's RMSPE: 0.06803	valid_1's RMSPE: 0.29302
# [2600]	training's RMSPE: 0.0656	valid_1's RMSPE: 0.29369
# [2700]	training's RMSPE: 0.06338	valid_1's RMSPE: 0.29422
# [2800]	training's RMSPE: 0.0613	valid_1's RMSPE: 0.29469
# [2900]	training's RMSPE: 0.05925	valid_1's RMSPE: 0.29495
# [3000]	training's RMSPE: 0.05743	valid_1's RMSPE: 0.29529
# [3100]	training's RMSPE: 0.0556	valid_1's RMSPE: 0.29581
# [3200]	training's RMSPE: 0.05381	valid_1's RMSPE: 0.29631
# [3300]	training's RMSPE: 0.05213	valid_1's RMSPE: 0.29656
# [3400]	training's RMSPE: 0.0506	valid_1's RMSPE: 0.29694
# [3500]	training's RMSPE: 0.04913	valid_1's RMSPE: 0.29738
# [3600]	training's RMSPE: 0.04762	valid_1's RMSPE: 0.29776
# [3700]	training's RMSPE: 0.04622	valid_1's RMSPE: 0.29809
# [3800]	training's RMSPE: 0.0449	valid_1's RMSPE: 0.29844
# [3900]	training's RMSPE: 0.04358	valid_1's RMSPE: 0.29874
# [4000]	training's RMSPE: 0.0423	valid_1's RMSPE: 0.29899
# [4100]	training's RMSPE: 0.04111	valid_1's RMSPE: 0.29921
# [4200]	training's RMSPE: 0.03998	valid_1's RMSPE: 0.29957
# [4300]	training's RMSPE: 0.03894	valid_1's RMSPE: 0.29983
# [4400]	training's RMSPE: 0.03788	valid_1's RMSPE: 0.30009
# [4500]	training's RMSPE: 0.03691	valid_1's RMSPE: 0.30033
# [4600]	training's RMSPE: 0.03597	valid_1's RMSPE: 0.30049
# [4700]	training's RMSPE: 0.03509	valid_1's RMSPE: 0.30062
# [4800]	training's RMSPE: 0.03425	valid_1's RMSPE: 0.30082
# [4900]	training's RMSPE: 0.03335	valid_1's RMSPE: 0.30099
# [5000]	training's RMSPE: 0.03252	valid_1's RMSPE: 0.30124
# C:\Users\yzho0040\Anaconda3\lib\site-packages\lightgbm\basic.py:1705: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is ['stock_id']
#   _log_warning('categorical_feature in Dataset is overridden.\n'
# [LightGBM] [Warning] bagging_fraction is set=0.9581058054813363, subsample=0.4615201756036703 will be ignored. Current value: bagging_fraction=0.9581058054813363
# [LightGBM] [Warning] bagging_fraction is set=0.9581058054813363, subsample=0.4615201756036703 will be ignored. Current value: bagging_fraction=0.9581058054813363
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.233885 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 20144
# [LightGBM] [Info] Number of data points in the train set: 343145, number of used features: 54
# [LightGBM] [Warning] bagging_fraction is set=0.9581058054813363, subsample=0.4615201756036703 will be ignored. Current value: bagging_fraction=0.9581058054813363
# C:\Users\yzho0040\Anaconda3\lib\site-packages\lightgbm\basic.py:1433: UserWarning: Overriding the parameters from Reference Dataset.
#   _log_warning('Overriding the parameters from Reference Dataset.')
# C:\Users\yzho0040\Anaconda3\lib\site-packages\lightgbm\basic.py:1245: UserWarning: categorical_column in param dict is overridden.
#   _log_warning('{} in param dict is overridden.'.format(cat_alias))
# [LightGBM] [Info] Start training from score 0.001795
# [100]	training's RMSPE: 0.20443	valid_1's RMSPE: 0.24032
# [200]	training's RMSPE: 0.18958	valid_1's RMSPE: 0.24641
# [300]	training's RMSPE: 0.17774	valid_1's RMSPE: 0.25132
# [400]	training's RMSPE: 0.16751	valid_1's RMSPE: 0.25572
# [500]	training's RMSPE: 0.15836	valid_1's RMSPE: 0.25924
# [600]	training's RMSPE: 0.1502	valid_1's RMSPE: 0.2624
# [700]	training's RMSPE: 0.14279	valid_1's RMSPE: 0.26521
# [800]	training's RMSPE: 0.13608	valid_1's RMSPE: 0.26739
# [900]	training's RMSPE: 0.12987	valid_1's RMSPE: 0.26923
# [1000]	training's RMSPE: 0.12401	valid_1's RMSPE: 0.2715
# [1100]	training's RMSPE: 0.11846	valid_1's RMSPE: 0.27304
# [1200]	training's RMSPE: 0.11323	valid_1's RMSPE: 0.27469
# [1300]	training's RMSPE: 0.10827	valid_1's RMSPE: 0.27626
# [1400]	training's RMSPE: 0.10365	valid_1's RMSPE: 0.27784
# [1500]	training's RMSPE: 0.09937	valid_1's RMSPE: 0.27918
# [1600]	training's RMSPE: 0.09532	valid_1's RMSPE: 0.28058
# [1700]	training's RMSPE: 0.09148	valid_1's RMSPE: 0.28175
# [1800]	training's RMSPE: 0.08806	valid_1's RMSPE: 0.28278
# [1900]	training's RMSPE: 0.08474	valid_1's RMSPE: 0.28372
# [2000]	training's RMSPE: 0.08156	valid_1's RMSPE: 0.28465
# [2100]	training's RMSPE: 0.07849	valid_1's RMSPE: 0.28538
# [2200]	training's RMSPE: 0.07566	valid_1's RMSPE: 0.28621
# [2300]	training's RMSPE: 0.07303	valid_1's RMSPE: 0.28702
# [2400]	training's RMSPE: 0.07037	valid_1's RMSPE: 0.28774
# [2500]	training's RMSPE: 0.06791	valid_1's RMSPE: 0.28837
# [2600]	training's RMSPE: 0.06562	valid_1's RMSPE: 0.28896
# [2700]	training's RMSPE: 0.06333	valid_1's RMSPE: 0.28959
# [2800]	training's RMSPE: 0.0612	valid_1's RMSPE: 0.29005
# [2900]	training's RMSPE: 0.05918	valid_1's RMSPE: 0.29071
# [3000]	training's RMSPE: 0.05719	valid_1's RMSPE: 0.29113
# [3100]	training's RMSPE: 0.05532	valid_1's RMSPE: 0.29158
# [3200]	training's RMSPE: 0.05365	valid_1's RMSPE: 0.29199
# [3300]	training's RMSPE: 0.05195	valid_1's RMSPE: 0.29247
# [3400]	training's RMSPE: 0.05037	valid_1's RMSPE: 0.29281
# [3500]	training's RMSPE: 0.04889	valid_1's RMSPE: 0.29309
# [3600]	training's RMSPE: 0.04733	valid_1's RMSPE: 0.29341
# [3700]	training's RMSPE: 0.0459	valid_1's RMSPE: 0.29366
# [3800]	training's RMSPE: 0.04458	valid_1's RMSPE: 0.29391
# [3900]	training's RMSPE: 0.04329	valid_1's RMSPE: 0.29415
# [4000]	training's RMSPE: 0.04212	valid_1's RMSPE: 0.29446
# [4100]	training's RMSPE: 0.04086	valid_1's RMSPE: 0.29472
# [4200]	training's RMSPE: 0.03969	valid_1's RMSPE: 0.29489
# [4300]	training's RMSPE: 0.03864	valid_1's RMSPE: 0.29511
# [4400]	training's RMSPE: 0.03761	valid_1's RMSPE: 0.29533
# [4500]	training's RMSPE: 0.03663	valid_1's RMSPE: 0.29555
# [4600]	training's RMSPE: 0.03573	valid_1's RMSPE: 0.29578
# [4700]	training's RMSPE: 0.03482	valid_1's RMSPE: 0.29598
# [4800]	training's RMSPE: 0.03396	valid_1's RMSPE: 0.29628
# [4900]	training's RMSPE: 0.03312	valid_1's RMSPE: 0.29648
# [5000]	training's RMSPE: 0.03229	valid_1's RMSPE: 0.29671
# C:\Users\yzho0040\Anaconda3\lib\site-packages\lightgbm\basic.py:1705: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is ['stock_id']
#   _log_warning('categorical_feature in Dataset is overridden.\n'
# [LightGBM] [Warning] bagging_fraction is set=0.9581058054813363, subsample=0.4615201756036703 will be ignored. Current value: bagging_fraction=0.9581058054813363
# [LightGBM] [Warning] bagging_fraction is set=0.9581058054813363, subsample=0.4615201756036703 will be ignored. Current value: bagging_fraction=0.9581058054813363
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.086867 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 20143
# [LightGBM] [Info] Number of data points in the train set: 343146, number of used features: 54
# [LightGBM] [Warning] bagging_fraction is set=0.9581058054813363, subsample=0.4615201756036703 will be ignored. Current value: bagging_fraction=0.9581058054813363
# C:\Users\yzho0040\Anaconda3\lib\site-packages\lightgbm\basic.py:1433: UserWarning: Overriding the parameters from Reference Dataset.
#   _log_warning('Overriding the parameters from Reference Dataset.')
# C:\Users\yzho0040\Anaconda3\lib\site-packages\lightgbm\basic.py:1245: UserWarning: categorical_column in param dict is overridden.
#   _log_warning('{} in param dict is overridden.'.format(cat_alias))
# [LightGBM] [Info] Start training from score 0.001800
# [100]	training's RMSPE: 0.20422	valid_1's RMSPE: 0.25187
# [200]	training's RMSPE: 0.18926	valid_1's RMSPE: 0.25436
# [300]	training's RMSPE: 0.17736	valid_1's RMSPE: 0.25899
# [400]	training's RMSPE: 0.1671	valid_1's RMSPE: 0.26271
# [500]	training's RMSPE: 0.15822	valid_1's RMSPE: 0.26598
# [600]	training's RMSPE: 0.15006	valid_1's RMSPE: 0.27094
# [700]	training's RMSPE: 0.14239	valid_1's RMSPE: 0.27359
# [800]	training's RMSPE: 0.13556	valid_1's RMSPE: 0.27623
# [900]	training's RMSPE: 0.12916	valid_1's RMSPE: 0.27955

# %% [markdown]
# ### Hyperparameter Tunning using Hyperopt

# %%
# from hyperopt import hp, fmin, tpe, Trials, STATUS_OK
# from hyperopt.pyll import scope

# %%
# lgb_reg_params = {
#     'learning_rate':    hp.uniform('learning_rate',0.01,1),
#     'max_depth':        hp.choice('max_depth', np.arange(2, 100, 1, dtype=int)),
#     'min_child_weight': hp.choice('min_child_weight', np.arange(1, 50, 1, dtype=int)),
#     'colsample_bytree': hp.uniform('colsample_bytree',0.1,1),
#     'subsample':        hp.uniform('subsample', 0.1, 1),
#     'num_leaves':       hp.choice('num_leaves', np.arange(1, 200, 1, dtype=int)),
#     'min_split_gain':   hp.uniform('min_split_gain', 0, 1),
#     'boosting_type':    hp.choice('boosting_type', ['dart', 'goss', 'gbdt']),
#     'reg_alpha':        hp.uniform('reg_alpha',0,1),
#     'reg_lambda':       hp.uniform('reg_lambda',0,1),
#     'n_estimators':     hp.choice('n_estimators', np.arange(5, 500, 5, dtype=int)),
#     'feature_fraction': hp.uniform('feature_fraction', 0.0, 1.0),
#     'bagging_fraction': hp.uniform('bagging_fraction', 0.0, 1.0)
# }

# %%
# param_hyperopt= {
#     'learning_rate': hp.loguniform('learning_rate', np.log(0.01), np.log(1)),
#     'max_depth': scope.int(hp.quniform('max_depth', 5, 40, 1)),
#     'n_estimators': scope.int(hp.quniform('n_estimators', 10, 500, 10)),
#     'num_leaves': scope.int(hp.quniform('num_leaves', 5, 50, 1)),
#     'boosting_type': hp.choice('boosting_type', ['dart', 'goss', 'gbdt']),
#     'reg_alpha': hp.uniform('reg_alpha', 0.0, 1.0)
#     'reg_lambda': hp.uniform('reg_lambda', 0.0, 1.0),
#     'colsample_bytree': hp.uniform('colsample_bytree', 0.0, 1.0)
# #     'feature_fraction': hp.uniform('feature_fraction', 0.0, 1.0),
# #     'bagging_fraction': hp.uniform('bagging_fraction', 0.0, 1.0),
# }

# %% [markdown]
# ### Cross Validation

# %%
# from sklearn.model_selection import KFold
# kf = KFold(n_splits=5, random_state=19901028, shuffle=True)

# %%
# scores = 0.0 
# models = []

# %%
# def f(params):
#     for fold, (trn_idx, val_idx) in enumerate(kf.split(X, y)):

#         print("Fold :", fold+1)
    
#         # create dataset
#         X_train, y_train = X.loc[trn_idx], y[trn_idx]
#         X_valid, y_valid = X.loc[val_idx], y[val_idx]

#         #RMSPE weight
#         weights = 1/np.square(y_train)
#         lgbm_train = lgbm.Dataset(X_train,y_train,weight = weights)

#         weights = 1/np.square(y_valid)
#         lgbm_valid = lgbm.Dataset(X_valid,y_valid,reference = lgbm_train,weight = weights)

#         # model 
#         model = lgbm.train(params=params,
#                            train_set=lgbm_train,
#                            valid_sets=[lgbm_train, lgbm_valid],
#                            num_boost_round=5000,
#                            feval=feval_RMSPE,
#                            verbose_eval=100,
#                            categorical_feature = ['stock_id']
#                          )

#         # validation 
#         y_pred = model.predict(X_valid, num_iteration=model.best_iteration)

#         RMSPE = round(rmspe(y_true = y_valid, y_pred = y_pred),3)
#         print(f'Performance of the　prediction: , RMSPE: {RMSPE}')

#         #keep scores and models
#         scores += RMSPE / 5
#         models.append(model)
#         print("*" * 100)
#     return scores

# %%
# trials = Trials()
# result = fmin(
#     fn=f,                           # objective function
#     space=lgb_reg_params,           # parameter space
#     algo=tpe.suggest,               # surrogate algorithm
#     max_evals=50,                   # no. of evaluations
#     trials=trials                   # trials object that keeps track of the sample results (optional)
# )
# print(result)
# Out:
# Fold :
# 1
#   0%|          | 0/50 [00:00<?, ?trial/s, best loss=?]
# C:\Users\yzho0040\Anaconda3\lib\site-packages\lightgbm\engine.py:148: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   _log_warning("Found `{}` in params. Will use it instead of argument".format(alias))
#
# C:\Users\yzho0040\Anaconda3\lib\site-packages\lightgbm\basic.py:1705: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is ['stock_id']
#   _log_warning('categorical_feature in Dataset is overridden.\n'
# [LightGBM] [Warning] feature_fraction is set=0.15398219972443217, colsample_bytree=0.7581888074491685 will be ignored. Current value: feature_fraction=0.15398219972443217
# [LightGBM] [Warning] bagging_fraction is set=0.2296291632527997, subsample=0.384468773812078 will be ignored. Current value: bagging_fraction=0.2296291632527997
# [LightGBM] [Warning] feature_fraction is set=0.15398219972443217, colsample_bytree=0.7581888074491685 will be ignored. Current value: feature_fraction=0.15398219972443217
# [LightGBM] [Warning] bagging_fraction is set=0.2296291632527997, subsample=0.384468773812078 will be ignored. Current value: bagging_fraction=0.2296291632527997
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.092698 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 13573
# [LightGBM] [Info] Number of data points in the train set: 343145, number of used features: 54
# [LightGBM] [Warning] feature_fraction is set=0.15398219972443217, colsample_bytree=0.7581888074491685 will be ignored. Current value: feature_fraction=0.15398219972443217
# [LightGBM] [Warning] bagging_fraction is set=0.2296291632527997, subsample=0.384468773812078 will be ignored. Current value: bagging_fraction=0.2296291632527997
#   0%|          | 0/50 [00:01<?, ?trial/s, best loss=?]
# C:\Users\yzho0040\Anaconda3\lib\site-packages\lightgbm\basic.py:1433: UserWarning: Overriding the parameters from Reference Dataset.
#   _log_warning('Overriding the parameters from Reference Dataset.')
#
# C:\Users\yzho0040\Anaconda3\lib\site-packages\lightgbm\basic.py:1245: UserWarning: categorical_column in param dict is overridden.
#   _log_warning('{} in param dict is overridden.'.format(cat_alias))
# [LightGBM] [Info] Start training from score 0.001800
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [100]	training's RMSPE: 0.22565	valid_1's RMSPE: 0.23432
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [200]	training's RMSPE: 0.22541	valid_1's RMSPE: 0.23416
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
#   0%|          | 0/50 [00:18<?, ?trial/s, best loss=?]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-150-ecce7bbdd8ba> in <module>
#       1 trials = Trials()
# ----> 2 result = fmin(
#       3     fn=f,                           # objective function
#       4     space=lgb_reg_params,           # parameter space
#       5     algo=tpe.suggest,               # surrogate algorithm
#
# ~\Anaconda3\lib\site-packages\hyperopt\fmin.py in fmin(fn, space, algo, max_evals, timeout, loss_threshold, trials, rstate, allow_trials_fmin, pass_expr_memo_ctrl, catch_eval_exceptions, verbose, return_argmin, points_to_evaluate, max_queue_len, show_progressbar, early_stop_fn, trials_save_file)
#     505
#     506     if allow_trials_fmin and hasattr(trials, "fmin"):
# --> 507         return trials.fmin(
#     508             fn,
#     509             space,
#
# ~\Anaconda3\lib\site-packages\hyperopt\base.py in fmin(self, fn, space, algo, max_evals, timeout, loss_threshold, max_queue_len, rstate, verbose, pass_expr_memo_ctrl, catch_eval_exceptions, return_argmin, show_progressbar, early_stop_fn, trials_save_file)
#     680         from .fmin import fmin
#     681
# --> 682         return fmin(
#     683             fn,
#     684             space,
#
# ~\Anaconda3\lib\site-packages\hyperopt\fmin.py in fmin(fn, space, algo, max_evals, timeout, loss_threshold, trials, rstate, allow_trials_fmin, pass_expr_memo_ctrl, catch_eval_exceptions, verbose, return_argmin, points_to_evaluate, max_queue_len, show_progressbar, early_stop_fn, trials_save_file)
#     551
#     552     # next line is where the fmin is actually executed
# --> 553     rval.exhaust()
#     554
#     555     if return_argmin:
#
# ~\Anaconda3\lib\site-packages\hyperopt\fmin.py in exhaust(self)
#     354     def exhaust(self):
#     355         n_done = len(self.trials)
# --> 356         self.run(self.max_evals - n_done, block_until_done=self.asynchronous)
#     357         self.trials.refresh()
#     358         return self
#
# ~\Anaconda3\lib\site-packages\hyperopt\fmin.py in run(self, N, block_until_done)
#     290                 else:
#     291                     # -- loop over trials and do the jobs directly
# --> 292                     self.serial_evaluate()
#     293
#     294                 self.trials.refresh()
#
# ~\Anaconda3\lib\site-packages\hyperopt\fmin.py in serial_evaluate(self, N)
#     168                 ctrl = base.Ctrl(self.trials, current_trial=trial)
#     169                 try:
# --> 170                     result = self.domain.evaluate(spec, ctrl)
#     171                 except Exception as e:
#     172                     logger.error("job exception: %s" % str(e))
#
# ~\Anaconda3\lib\site-packages\hyperopt\base.py in evaluate(self, config, ctrl, attach_attachments)
#     905                 print_node_on_error=self.rec_eval_print_node_on_error,
#     906             )
# --> 907             rval = self.fn(pyll_rval)
#     908
#     909         if isinstance(rval, (float, int, np.number)):
#
# <ipython-input-149-9f92f513e6f6> in f(params)
#      16
#      17         # model
# ---> 18         model = lgbm.train(params=params,
#      19                            train_set=lgbm_train,
#      20                            valid_sets=[lgbm_train, lgbm_valid],
#
# ~\Anaconda3\lib\site-packages\lightgbm\engine.py in train(params, train_set, num_boost_round, valid_sets, valid_names, fobj, feval, init_model, feature_name, categorical_feature, early_stopping_rounds, evals_result, verbose_eval, learning_rates, keep_training_booster, callbacks)
#     254             if is_valid_contain_train:
#     255                 evaluation_result_list.extend(booster.eval_train(feval))
# --> 256             evaluation_result_list.extend(booster.eval_valid(feval))
#     257         try:
#     258             for cb in callbacks_after_iter:
#
# ~\Anaconda3\lib\site-packages\lightgbm\basic.py in eval_valid(self, feval)
#    2886             List with evaluation results.
#    2887         """
# -> 2888         return [item for i in range(1, self.__num_dataset)
#    2889                 for item in self.__inner_eval(self.name_valid_sets[i - 1], i, feval)]
#    2890
#
# ~\Anaconda3\lib\site-packages\lightgbm\basic.py in <listcomp>(.0)
#    2887         """
#    2888         return [item for i in range(1, self.__num_dataset)
# -> 2889                 for item in self.__inner_eval(self.name_valid_sets[i - 1], i, feval)]
#    2890
#    2891     def save_model(self, filename, num_iteration=None, start_iteration=0, importance_type='split'):
#
# ~\Anaconda3\lib\site-packages\lightgbm\basic.py in __inner_eval(self, data_name, data_idx, feval)
#    3400                 if eval_function is None:
#    3401                     continue
# -> 3402                 feval_ret = eval_function(self.__inner_predict(data_idx), cur_data)
#    3403                 if isinstance(feval_ret, list):
#    3404                     for eval_name, val, is_higher_better in feval_ret:
#
# ~\Anaconda3\lib\site-packages\lightgbm\basic.py in __inner_predict(self, data_idx)
#    3423             tmp_out_len = ctypes.c_int64(0)
#    3424             data_ptr = self.__inner_predict_buffer[data_idx].ctypes.data_as(ctypes.POINTER(ctypes.c_double))
# -> 3425             _safe_call(_LIB.LGBM_BoosterGetPredict(
#    3426                 self.handle,
#    3427                 ctypes.c_int(data_idx),
#
# KeyboardInterrupt:

# %%
if result['boosting_type']==0:
    result['boosting_type'] = 'dart'
elif result['boosting_type']==1:
    result['boosting_type'] = 'goss'
else:
    result['boosting_type'] = 'gbdt'

# %%
f(result)

# %%
model

# %% [markdown]
# # Test set

# %%
y_pred = df_test[['row_id']]
X_test = df_test.drop(['time_id', 'row_id'], axis = 1)

# %%
X_test
# Out:
#    stock_id  log_return_realized_volatility  log_return2_realized_volatility  \
# 0         0                        0.000294                         0.000252
# 1         0                             NaN                              NaN
# 2         0                             NaN                              NaN
#
#    wap_balance_mean  price_spread_mean  bid_spread_mean  ask_spread_mean  \
# 0          0.000145           0.000557         0.000393        -0.000115
# 1               NaN                NaN              NaN              NaN
# 2               NaN                NaN              NaN              NaN
#
#    volume_imbalance_mean  total_volume_mean  wap_mean  \
# 0             164.666667         350.666667  1.000405
# 1                    NaN                NaN       NaN
# 2                    NaN                NaN       NaN
#
#    log_return_realized_volatility_400  log_return2_realized_volatility_400  \
# 0                                 NaN                                  NaN
# 1                                 NaN                                  NaN
# 2                                 NaN                                  NaN
#
#    wap_balance_mean_400  price_spread_mean_400  bid_spread_mean_400  \
# 0                   NaN                    NaN                  NaN
# 1                   NaN                    NaN                  NaN
# 2                   NaN                    NaN                  NaN
#
#    ask_spread_mean_400  volume_imbalance_mean_400  total_volume_mean_400  \
# 0                  NaN                        NaN                    NaN
# 1                  NaN                        NaN                    NaN
# 2                  NaN                        NaN                    NaN
#
#    wap_mean_400  log_return_realized_volatility_300  \
# 0           NaN                                 NaN
# 1           NaN                                 NaN
# 2           NaN                                 NaN
#
#    log_return2_realized_volatility_300  wap_balance_mean_300  \
# 0                                  NaN                   NaN
# 1                                  NaN                   NaN
# 2                                  NaN                   NaN
#
#    price_spread_mean_300  bid_spread_mean_300  ask_spread_mean_300  \
# 0                    NaN                  NaN                  NaN
# 1                    NaN                  NaN                  NaN
# 2                    NaN                  NaN                  NaN
#
#    volume_imbalance_mean_300  total_volume_mean_300  wap_mean_300  \
# 0                        NaN                    NaN           NaN
# 1                        NaN                    NaN           NaN
# 2                        NaN                    NaN           NaN
#
#    log_return_realized_volatility_200  log_return2_realized_volatility_200  \
# 0                                 NaN                                  NaN
# 1                                 NaN                                  NaN
# 2                                 NaN                                  NaN
#
#    wap_balance_mean_200  price_spread_mean_200  bid_spread_mean_200  \
# 0                   NaN                    NaN                  NaN
# 1                   NaN                    NaN                  NaN
# 2                   NaN                    NaN                  NaN
#
#    ask_spread_mean_200  volume_imbalance_mean_200  total_volume_mean_200  \
# 0                  NaN                        NaN                    NaN
# 1                  NaN                        NaN                    NaN
# 2                  NaN                        NaN                    NaN
#
#    wap_mean_200  trade_log_return_realized_volatility  \
# 0           NaN                              0.000295
# 1           NaN                                   NaN
# 2           NaN                                   NaN
#
#    trade_seconds_in_bucket_count_unique  trade_size_sum  \
# 0                                   3.0           201.0
# 1                                   NaN             NaN
# 2                                   NaN             NaN
#
#    trade_order_count_mean  trade_log_return_realized_volatility_400  \
# 0                3.666667                                       NaN
# 1                     NaN                                       NaN
# 2                     NaN                                       NaN
#
#    trade_seconds_in_bucket_count_unique_400  trade_size_sum_400  \
# 0                                       NaN                 NaN
# 1                                       NaN                 NaN
# 2                                       NaN                 NaN
#
#    trade_order_count_mean_400  trade_log_return_realized_volatility_300  \
# 0                         NaN                                       NaN
# 1                         NaN                                       NaN
# 2                         NaN                                       NaN
#
#    trade_seconds_in_bucket_count_unique_300  trade_size_sum_300  \
# 0                                       NaN                 NaN
# 1                                       NaN                 NaN
# 2                                       NaN                 NaN
#
#    trade_order_count_mean_300  trade_log_return_realized_volatility_200  \
# 0                         NaN                                       NaN
# 1                         NaN                                       NaN
# 2                         NaN                                       NaN
#
#    trade_seconds_in_bucket_count_unique_200  trade_size_sum_200  \
# 0                                       NaN                 NaN
# 1                                       NaN                 NaN
# 2                                       NaN                 NaN
#
#    trade_order_count_mean_200  stock_id_target_enc
# 0                         NaN             0.004028
# 1                         NaN             0.004028
# 2                         NaN             0.004028

# %%
model.fit(X,y)
# Out:
# C:\Users\yzho0040\Anaconda3\lib\site-packages\lightgbm\engine.py:153: UserWarning: Found `early_stopping_rounds` in params. Will use it instead of argument
#   _log_warning("Found `{}` in params. Will use it instead of argument".format(alias))
# [LightGBM] [Warning] feature_fraction is set=0.6539607982625899, colsample_bytree=0.3676292462136665 will be ignored. Current value: feature_fraction=0.6539607982625899
# [LightGBM] [Warning] bagging_fraction is set=0.5786962235763202, subsample=0.4024465891223342 will be ignored. Current value: bagging_fraction=0.5786962235763202
# LGBMRegressor(bagging_fraction=0.5786962235763202, boosting_type='goss',
#               colsample_bytree=0.3676292462136665, early_stopping_rounds=None,
#               feature_fraction=0.6539607982625899,
#               learning_rate=0.737114518760958, max_depth=78,
#               min_child_weight=46, min_split_gain=0.0016060416701769668,
#               n_estimators=47, num_leaves=72, reg_alpha=0.3966088097347819,
#               reg_lambda=0.14110438421198862, subsample=0.4024465891223342)

# %%
pred = model.predict(X_test[X.columns])

# %%
y_pred = y_pred.assign(target = pred)

# %%
y_pred
# Out:
#   row_id    target
# 0    0-4  0.001643
# 1   0-32  0.001643
# 2   0-34  0.001643

# %%
y_pred.to_csv('submission.csv',index = False)

# %%
X_test
# Out:
#    stock_id  log_return_realized_volatility  log_return2_realized_volatility  \
# 0         0                        0.000294                         0.000252
# 1         0                             NaN                              NaN
# 2         0                             NaN                              NaN
#
#    wap_balance_mean  price_spread_mean  bid_spread_mean  ask_spread_mean  \
# 0          0.000145           0.000557         0.000393        -0.000115
# 1               NaN                NaN              NaN              NaN
# 2               NaN                NaN              NaN              NaN
#
#    volume_imbalance_mean  total_volume_mean  wap_mean  \
# 0             164.666667         350.666667  1.000405
# 1                    NaN                NaN       NaN
# 2                    NaN                NaN       NaN
#
#    log_return_realized_volatility_400  log_return2_realized_volatility_400  \
# 0                                 NaN                                  NaN
# 1                                 NaN                                  NaN
# 2                                 NaN                                  NaN
#
#    wap_balance_mean_400  price_spread_mean_400  bid_spread_mean_400  \
# 0                   NaN                    NaN                  NaN
# 1                   NaN                    NaN                  NaN
# 2                   NaN                    NaN                  NaN
#
#    ask_spread_mean_400  volume_imbalance_mean_400  total_volume_mean_400  \
# 0                  NaN                        NaN                    NaN
# 1                  NaN                        NaN                    NaN
# 2                  NaN                        NaN                    NaN
#
#    wap_mean_400  log_return_realized_volatility_300  \
# 0           NaN                                 NaN
# 1           NaN                                 NaN
# 2           NaN                                 NaN
#
#    log_return2_realized_volatility_300  wap_balance_mean_300  \
# 0                                  NaN                   NaN
# 1                                  NaN                   NaN
# 2                                  NaN                   NaN
#
#    price_spread_mean_300  bid_spread_mean_300  ask_spread_mean_300  \
# 0                    NaN                  NaN                  NaN
# 1                    NaN                  NaN                  NaN
# 2                    NaN                  NaN                  NaN
#
#    volume_imbalance_mean_300  total_volume_mean_300  wap_mean_300  \
# 0                        NaN                    NaN           NaN
# 1                        NaN                    NaN           NaN
# 2                        NaN                    NaN           NaN
#
#    log_return_realized_volatility_200  log_return2_realized_volatility_200  \
# 0                                 NaN                                  NaN
# 1                                 NaN                                  NaN
# 2                                 NaN                                  NaN
#
#    wap_balance_mean_200  price_spread_mean_200  bid_spread_mean_200  \
# 0                   NaN                    NaN                  NaN
# 1                   NaN                    NaN                  NaN
# 2                   NaN                    NaN                  NaN
#
#    ask_spread_mean_200  volume_imbalance_mean_200  total_volume_mean_200  \
# 0                  NaN                        NaN                    NaN
# 1                  NaN                        NaN                    NaN
# 2                  NaN                        NaN                    NaN
#
#    wap_mean_200  trade_log_return_realized_volatility  \
# 0           NaN                              0.000295
# 1           NaN                                   NaN
# 2           NaN                                   NaN
#
#    trade_seconds_in_bucket_count_unique  trade_size_sum  \
# 0                                   3.0           201.0
# 1                                   NaN             NaN
# 2                                   NaN             NaN
#
#    trade_order_count_mean  trade_log_return_realized_volatility_400  \
# 0                3.666667                                       NaN
# 1                     NaN                                       NaN
# 2                     NaN                                       NaN
#
#    trade_seconds_in_bucket_count_unique_400  trade_size_sum_400  \
# 0                                       NaN                 NaN
# 1                                       NaN                 NaN
# 2                                       NaN                 NaN
#
#    trade_order_count_mean_400  trade_log_return_realized_volatility_300  \
# 0                         NaN                                       NaN
# 1                         NaN                                       NaN
# 2                         NaN                                       NaN
#
#    trade_seconds_in_bucket_count_unique_300  trade_size_sum_300  \
# 0                                       NaN                 NaN
# 1                                       NaN                 NaN
# 2                                       NaN                 NaN
#
#    trade_order_count_mean_300  trade_log_return_realized_volatility_200  \
# 0                         NaN                                       NaN
# 1                         NaN                                       NaN
# 2                         NaN                                       NaN
#
#    trade_seconds_in_bucket_count_unique_200  trade_size_sum_200  \
# 0                                       NaN                 NaN
# 1                                       NaN                 NaN
# 2                                       NaN                 NaN
#
#    trade_order_count_mean_200  stock_id_target_enc
# 0                         NaN             0.004028
# 1                         NaN             0.004028
# 2                         NaN             0.004028
